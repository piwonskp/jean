# %%
from ipynb.fs.full.jean.common._1load import appls
import seaborn as sns

# %%
appls.head()
# Out:
#    Numer dokumentu     Data złożenia   Data zamknięcia  \
# 0              565  13.10.2017 09:26  14.10.2017 08:56
# 1              111  15.09.2017 17:02  19.09.2017 16:05
# 2              294  18.09.2017 22:57  19.09.2017 16:27
# 3               13  14.09.2017 10:16  15.09.2017 13:38
# 4              301  18.09.2017 23:29  19.09.2017 16:29
#
#                   Student Tryb studiów Typ studiów Język wykładowy  \
# 0  WqAdrXQFVXEuVFbBNi8ZYw            D           I              PL
# 1  b7uHtLHmJCf40Cj27vMhVg            Z           I              PL
# 2   DjOIoCquSJwSIQ96XqbiQ            Z           I              PL
# 3    cKN0GNsJejbI3uFXBTlw            D           I              PL
# 4  EJ0ALSHjEfgLOOCgPO0RjA            Z           I              PL
#
#                                             Kierunek  \
# 0         Model 2,I,D,PL,7 - Inżynieria  Komputerowa
# 1  Model 2,I,Z,PL,8 - Technika Wysokich Napięć i ...
# 2               Model 2,I,Z,PL,8 - Elektroenergetyka
# ...

# %%
_ = appls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5883 entries, 0 to 5882
# Data columns (total 43 columns):
# Numer dokumentu                              5883 non-null int64
# Data złożenia                                5883 non-null object
# Data zamknięcia                              5883 non-null object
# Student                                      5883 non-null object
# Tryb studiów                                 5883 non-null object
# Typ studiów                                  5883 non-null object
# Język wykładowy                              5883 non-null object
# Kierunek                                     5883 non-null object
# Status                                       5883 non-null object
# Rodzaj wniosku                               5883 non-null object
# Osoba przyjmująca                            5873 non-null object
# Osoba przypisana                             5879 non-null object
# Słowo regulamin w uzasadnieniu               5883 non-null object
# ...

# %%
appls.describe()
# Out:
#        Numer dokumentu  Liczba załączników  Liczba zmian statusu  \
# count      5883.000000         5883.000000           5883.000000
# mean       3194.697943            0.529152              4.803842
# std        1827.308481            0.719117              1.747959
# min           5.000000            0.000000              2.000000
# 25%        1630.500000            0.000000              4.000000
# 50%        3191.000000            0.000000              4.000000
# 75%        4776.500000            1.000000              6.000000
# max        6366.000000           18.000000             24.000000
#
#        Semestr studiow  Brakujace ECTS  ECTS uznane w bieżącym semstrze  \
# count      5883.000000     5883.000000                      5883.000000
# mean          4.294238       25.784974                         6.130036
# std           2.162541       18.171830                        15.418483
# min           1.000000        0.000000                         0.000000
# ...

# %%
_ =sns.countplot(y=appls['Status'])

# %%
_ = sns.countplot(appls['Semestr rejestracji'])
