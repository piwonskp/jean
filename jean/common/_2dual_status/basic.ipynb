# %%
import seaborn as sns
import matplotlib.pyplot as plt

from ipynb.fs.full.jean.common._2dual_status import appls

# %%
_ = sns.countplot(y='Rodzaj wniosku', hue='accepted', data=appls)

# %%
y = appls[appls['Liczba załączników'] > 0 ]
_ = appls.hist("Liczba załączników", by='Rodzaj wniosku', figsize=(20, 10))
